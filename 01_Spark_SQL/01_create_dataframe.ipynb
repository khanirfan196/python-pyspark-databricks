# %%
# Copy this code in every notebook's first cell

import sys
import os

# Adds the parent directory (main project folder) to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Now Python can see outside the 01_Spark_SQL folder
from spark_configuration.spark_config import get_spark
spark = get_spark()

# %%
spark.active()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://127.0.0.1:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LocalNotebookSession</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [("Python 3.12", "Working perfectly!"), ("PySpark", "Environment Fixed!")]
df = spark.createDataFrame(data, ["Environment", "Status"])

# %%
df.show()
# Out:
# +-----------+------------------+
# |Environment|            Status|
# +-----------+------------------+
# |Python 3.12|Working perfectly!|
# |    PySpark|Environment Fixed!|
# +-----------+------------------+

# %%
from pyspark.sql.types import *
